# %%
print("omg jupyter")
# Out:
# omg jupyter

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
a=np.array([(1,2,3), (4,5,6)])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ##Numpy Operations

# %%
a=np.array([(1,2,3), (4,5,6)])
a.ndim
# Out:
# 2

# %%
a=np.array([["C", "H", "R"],
            ["banana", "strawberry", "I"],
            ["S","orange","kiwi"]])

word=a[0,0] + a[0,1] + a[0,2] + a[1,2] + a[2,0]
print(word)
# Out:
# CHRIS

# %%
import numpy as np

a=np.array([[2,3,4,5], 
            [7,5,4,3], 
            [6,9,10,11] , 
            [15,17,89,29]])

#array[start:end:step]1

print(a[0:4:2])
# Out:
# [[ 2  3  4  5]
#  [ 6  9 10 11]]
